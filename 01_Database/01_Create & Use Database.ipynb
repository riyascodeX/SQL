# %% [markdown]
# # MySQL DATABASE CONNECTION

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost:3306/

# %% [markdown]
# # 1. VIEW ALL DATABASES

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 5 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pydb',),
#  ('sql_learn',)]

# %% [markdown]
# # 2. REMOVE OLDER VERSION BECAUSE DUPLICATE ERRORS

# %%
# %%sql
# DROP DATABASE IF EXISTS sql_learn;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 9 rows affected.
# []

# %% [markdown]
# # 4. CREATE THE FRESH DATABASE

# %%
# %%sql
# CREATE DATABASE sql_learn;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 1 rows affected.
# []

# %% [markdown]
# # 5. CHECK DATABASE CREATED OR NOT

# %%
# %%sql
# SHOW DATABASES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 5 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pydb',),
#  ('sql_learn',)]

# %% [markdown]
# # 6. ACTIVATE DATABASE

# %%
# %%sql
# USE sql_learn;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []
