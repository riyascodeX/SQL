# %% [markdown]
# # MySQL DATABASE CONNECTION

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost:3306/

# %% [markdown]
# # ACTIVATE DATABASE

# %%
# %%sql
# use sql_learn;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
SYNTAX :
CREATE TABLE table_name (
    column_name INT,
    column_name VARCHAR(100),
    column_name DECIMAL(10,2),
    column_name DATE,
    column_name DATETIME,
    column_name BOOLEAN
);

# %% [markdown]
# # 1. INT

# %%
# %%sql
# CREATE TABLE int_example (
#     id INT,
#     age INT
# );
#
# INSERT INTO int_example
# VALUES
# (1, 22),
# (2, 25),
# (3, 30);
#
# SELECT * FROM int_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, 22), (2, 25), (3, 30)]

# %% [markdown]
# # 2. DECIMAL

# %%
# %%sql
# CREATE TABLE decimal_example (
#     id INT,
#     price DECIMAL(10,2)
# );
#
# INSERT INTO decimal_example
# VALUES
# (1, 55000.50),
# (2, 799.99),
# (3, 1200.00);
#
# SELECT * FROM decimal_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, Decimal('55000.50')), (2, Decimal('799.99')), (3, Decimal('1200.00'))]

# %% [markdown]
# # 3. VARCHAR

# %%
# %%sql
# CREATE TABLE varchar_example (
#     id INT,
#     name VARCHAR(100)
# );
#
# INSERT INTO varchar_example
# VALUES
# (1, 'Arun'),
# (2, 'Priya'),
# (3, 'Rahul');
#
# SELECT * FROM varchar_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, 'Arun'), (2, 'Priya'), (3, 'Rahul')]

# %% [markdown]
# # 4. CHAR

# %%
# %%sql
# CREATE TABLE char_example (
#     id INT,
#     country_code CHAR(2)
# );
#
# INSERT INTO char_example
# VALUES
# (1, 'IN'),
# (2, 'US'),
# (3, 'UK');
#
# SELECT * FROM char_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, 'IN'), (2, 'US'), (3, 'UK')]

# %% [markdown]
# # 5. TEXT

# %%
# %%sql
# CREATE TABLE text_example (
#     id INT,
#     description TEXT
# );
#
# INSERT INTO text_example
# VALUES
# (1, 'SQL beginner'),
# (2, 'Learning MySQL'),
# (3, 'Practicing SQL queries');
#
# SELECT * FROM text_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, 'SQL beginner'), (2, 'Learning MySQL'), (3, 'Practicing SQL queries')]

# %% [markdown]
# # 6. DATE

# %%
# %%sql
# CREATE TABLE date_example (
#     id INT,
#     joining_date DATE
# );
#
# INSERT INTO date_example
# VALUES
# (1, '2025-01-10'),
# (2, '2025-02-15'),
# (3, '2025-03-20');
#
# SELECT * FROM date_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, datetime.date(2025, 1, 10)),
#  (2, datetime.date(2025, 2, 15)),
#  (3, datetime.date(2025, 3, 20))]

# %% [markdown]
# # 7. TIME

# %%
# %%sql
# CREATE TABLE time_example (
#     id INT,
#     login_time TIME
# );
#
# INSERT INTO time_example
# VALUES
# (1, '09:30:00'),
# (2, '10:15:00'),
# (3, '11:45:00');
#
# SELECT * FROM time_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, datetime.timedelta(seconds=34200)),
#  (2, datetime.timedelta(seconds=36900)),
#  (3, datetime.timedelta(seconds=42300))]

# %% [markdown]
# # 8. DATETIME

# %%
# %%sql
# CREATE TABLE datetime_example (
#     id INT,
#     created_at DATETIME
# );
#
# INSERT INTO datetime_example
# VALUES
# (1, '2025-01-10 09:30:00'),
# (2, '2025-02-15 10:15:00'),
# (3, '2025-03-20 11:45:00');
#
# SELECT * FROM datetime_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, datetime.datetime(2025, 1, 10, 9, 30)),
#  (2, datetime.datetime(2025, 2, 15, 10, 15)),
#  (3, datetime.datetime(2025, 3, 20, 11, 45))]

# %% [markdown]
# # 9. TIMESTAMP

# %%
# %%sql
# CREATE TABLE timestamp_example (
#     id INT,
#     created_at TIMESTAMP
# );
#
# INSERT INTO timestamp_example
# VALUES
# (1, '2025-01-10 09:30:00'),
# (2, '2025-02-15 10:15:00'),
# (3, '2025-03-20 11:45:00');
#
# SELECT * FROM timestamp_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, datetime.datetime(2025, 1, 10, 9, 30)),
#  (2, datetime.datetime(2025, 2, 15, 10, 15)),
#  (3, datetime.datetime(2025, 3, 20, 11, 45))]

# %% [markdown]
# # 10. BOOLEAN

# %%
# %%sql
# CREATE TABLE boolean_example (
#     id INT,
#     is_active BOOLEAN
# );
#
# INSERT INTO boolean_example
# VALUES
# (1, TRUE),
# (2, FALSE),
# (3, TRUE);
#
# SELECT * FROM boolean_example;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, 1), (2, 0), (3, 1)]
