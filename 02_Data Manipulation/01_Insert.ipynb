# %% [markdown]
# # MySQL DATABASE CONNECTION

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost:3306/

# %% [markdown]
# # ACTIVATE DATABASE

# %%
# %%sql
# use sql_learn;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %% [markdown]
# # CREATE TABLE

# %%
# %%sql
# CREATE TABLE insert_students (
#     student_id INT,
#     student_name VARCHAR(100),
#     age INT
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %% [markdown]
# # SYNTAX :

# %%
'''INSERT INTO table_name (column1, column2, column3)
    VALUES (value1, value2, value3);'''

# %% [markdown]
# # 1. INSERT SINGLE ROWS

# %%
# %%sql
# INSERT INTO insert_students (student_id, student_name, age)
# VALUES (1, 'Arun', 22);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 1 rows affected.
# []

# %% [markdown]
# # 1.1 CHECK SINGLE ROW DATA

# %%
# %%sql
# select * from insert_students;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 1 rows affected.
# [(1, 'Arun', 22)]

# %% [markdown]
# # SYNTAX :

# %%
''''INSERT INTO table_name (column1, column2, column3)
        VALUES
        (value1, value2, value3),
        (value4, value5, value6),
        (value7, value8, value9);'''

# %% [markdown]
# # 2. INSERT MULTIPLE ROWS

# %%
# %%sql
# INSERT INTO insert_students (student_id, student_name, age)
# VALUES
# (2, 'Priya', 21),
# (3, 'Rahul', 23),
# (4, 'Meena', 22);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 3 rows affected.
# []

# %% [markdown]
# # 2.2 CHECK MULTIPLE ROW DATA

# %%
# %%sql
# SELECT * FROM insert_students
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 4 rows affected.
# [(1, 'Arun', 22), (2, 'Priya', 21), (3, 'Rahul', 23), (4, 'Meena', 22)]
