# %% [markdown]
# # MySQL DATABASE CONNECTION

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost:3306/

# %% [markdown]
# # ACTIVATE DATABASE

# %%
# %%sql
# use sql_learn;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %% [markdown]
# # CREATE TABLE

# %%
# %%sql
# CREATE TABLE students_truncate (
#     student_id INT,
#     student_name VARCHAR(100),
#     age INT
# );
#
# # INSERT DATA
# INSERT INTO students_truncate
# (student_id, student_name, age)
# VALUES
# (1, 'Arun', 22),
# (2, 'Priya', 21),
# (3, 'Rahul', 23);
#
# # CHECK BEFORE TRUNCATE
# SELECT * FROM students_truncate;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(1, 'Arun', 22), (2, 'Priya', 21), (3, 'Rahul', 23)]

# %% [markdown]
# # SYNTAX :

# %%
''' TRUNCATE TABLE table_name; '''

# %% [markdown]
# # 1. TRUNCATE

# %%
# %%sql
# TRUNCATE TABLE students_truncate;
#
# # CHECK DATA
# SELECT * FROM students_truncate;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# 0 rows affected.
# []
