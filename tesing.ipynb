# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost:3306/

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 21 rows affected.
# [('aggregation',),
#  ('casewhen',),
#  ('constraints',),
#  ('date_funtion',),
#  ('datefunc',),
#  ('groceryl',),
#  ('information_schema',),
#  ('leetcode5',),
#  ('leetcode_1',),
#  ('mysql',),
#  ('normalization',),
#  ('part',),
#  ('performance_schema',),
#  ('pydb',),
#  ('riyas',),
#  ('sakila',),
#  ('sys',),
#  ('tcl_command',),
#  ('view',),
#  ('where_condition',),
#  ('window_function',)]
